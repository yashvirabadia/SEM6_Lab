# %% [markdown]
# <pre>
# <center><b><h1>Machine Learning</b></center>
#
# <center><b><h1>Lab - 3</b></center>
# <pre>

# %% [markdown]
# # 📱 Lab: Scikit-Learn Fundamentals (Google Play Store)
#
# **Objective:** Transition from manual data cleaning to automated Machine Learning preprocessing using Scikit-Learn.
#
# **Prerequisites:**
# * Ensure you have the `googleplaystore_cleaned.csv` file (from the previous lab) in this folder.

# %% [markdown]
# ### 1. Load Preprocessed Data
# **Instruction:** Load the dataset you cleaned in the previous lab. This dataset should already have `Installs`, `Price`, and `Reviews` converted to numbers.

# %%
import numpy as np
import pandas as pd 
import matplotlib as mlt

# %%
df = pd.read_csv("GooglePlayStore1.csv")
df
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1                                Coloring book moana
# 2              2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3              3                              Sketch - Draw & Paint
# 4              4              Pixel Draw - Number Art Coloring Book
# ...          ...                                                ...
# 7413       10833                                        Chemin (fr)
# 7414       10834                                      FR Calculator
# 7415       10836                                   Sya9a Maroc - FR
# 7416       10837                   Fr. Mike Schmitz Audio Teachings
# 7417       10840      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews        Size    Installs  Type  \
# 0          ART_AND_DESIGN     4.1      159  19000000.0     10000.0  Free
# 1          ART_AND_DESIGN     3.9      967  14000000.0    500000.0  Free
# 2          ART_AND_DESIGN     4.7    87510   8700000.0   5000000.0  Free
# 3          ART_AND_DESIGN     4.5   215644  25000000.0  50000000.0  Free
# 4          ART_AND_DESIGN     4.3      967   2800000.0    100000.0  Free
# ...                   ...     ...      ...         ...         ...   ...
# 7413  BOOKS_AND_REFERENCE     4.8       44    619000.0      1000.0  Free
# 7414               FAMILY     4.0        7   2600000.0       500.0  Free
# 7415               FAMILY     4.5       38  53000000.0      5000.0  Free
# 7416               FAMILY     5.0        4   3600000.0       100.0  Free
# 7417            LIFESTYLE     4.5   398307  19000000.0  10000000.0  Free
#
#       Price Content Rating                     Genres      Last Updated  \
# 0       0.0       Everyone               Art & Design   January 7, 2018
# 1       0.0       Everyone  Art & Design;Pretend Play  January 15, 2018
# 2       0.0       Everyone               Art & Design    August 1, 2018
# 3       0.0           Teen               Art & Design      June 8, 2018
# 4       0.0       Everyone    Art & Design;Creativity     June 20, 2018
# ...     ...            ...                        ...               ...
# 7413    0.0       Everyone          Books & Reference    March 23, 2014
# 7414    0.0       Everyone                  Education     June 18, 2017
# 7415    0.0       Everyone                  Education     July 25, 2017
# 7416    0.0       Everyone                  Education      July 6, 2018
# 7417    0.0       Everyone                  Lifestyle     July 25, 2018
#
#              Current Ver         Android Ver
# 0                  1.0.0        4.0.3 and up
# 1                  2.0.0        4.0.3 and up
# 2                  1.2.4        4.0.3 and up
# 3     Varies with device          4.2 and up
# 4                    1.1          4.4 and up
# ...                  ...                 ...
# 7413                 0.8          2.2 and up
# 7414               1.0.0          4.1 and up
# 7415                1.48          4.1 and up
# 7416                 1.0          4.1 and up
# 7417  Varies with device  Varies with device
#
# [7418 rows x 14 columns]

# %% [markdown]
# ### Intro to Scikit-Learn
# **What is Scikit-Learn?**
# It is the standard library for Machine Learning in Python. We use it for:
# 1.  **Preprocessing:** Scaling numbers and encoding text.
# 2.  **Modeling:** Training algorithms.
# 3.  **Evaluation:** Checking accuracy.
#
# **Task:** Import `sklearn` and check the version.

# %%
import sklearn

# %%
##__version__
print(sklearn.__version__)
# Out:
# 1.5.1

# %% [markdown]
# ### 3.  Train_Test_Split
# **Concept:** We split data to prevent "Overfitting". The model learns from the **Train** set and is tested on the **Test** set.
#
# **Task:**
# 1. Define `X` (Features: everything except Rating/App) and `y` (Target: Rating).
# 2. Split the data (80% Train, 20% Test).

# %%
# train_test_split
from sklearn.model_selection import train_test_split

x = df.drop(['Rating','App'],axis=1)
y = df['Rating']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print(f"Training shape : {x_train.shape}")
print(f"Training test: {x_test.shape}")
# Out:
# Training shape : (5934, 12)
# Training test: (1484, 12)

# %% [markdown]
# ### 4. 📏 Scaling Numerical Data (StandardScaler)
# **Concept:** `Installs` (Millions) are much larger than `Rating` (1-5). We scale them so the model treats them equally.
#
# **Task:** Use `StandardScaler` on the numerical columns.

# %%
#StandardScaler()
#fit_transform()
from sklearn.preprocessing import StandardScaler

num_col = ['Reviews','Size','Installs','Price']
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train[num_col])
print("Scaled data sample:")
x_train_scaled
# Out:
# Scaled data sample:
# array([[ 4.71711836, -0.24503439,  2.29217609, -0.06509976],
#        [-0.15315105, -0.83095407, -0.17003828, -0.06509976],
#        [-0.06480664,  0.99523354,  0.07596153, -0.06509976],
#        ...,
#        [-0.05483921,  0.65309066, -0.0471615 , -0.06509976],
#        [-0.1514681 , -0.65132906, -0.16782207, -0.06509976],
#        [-0.15330626, -0.6384987 , -0.1701614 , -0.06509976]])

# %% [markdown]
# ### 5. 🔠 Encoding Categorical Data
# **Concept:** Models need numbers, not text like "Business" or "Teen".
#
# **Method A: Pandas `get_dummies` (Simple)**

# %%
#get_dummies
dummies = pd.get_dummies(x_train['Content Rating'])
dummies.head()
# Out:
#       Everyone  Everyone 10+  Mature 17+   Teen  Unrated
# 5022      True         False       False  False    False
# 4195      True         False       False  False    False
# 1049      True         False       False  False    False
# 626       True         False       False  False    False
# 2022      True         False       False  False    False

# %% [markdown]
# **Method B: Sklearn `OneHotEncoder` (Professional)**

# %%
#OneHotEncoder
#fit_transform
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(handle_unknown='ignore')

cat_encoded = encoder.fit_transform(x_train[['Category']])

print("Encoded shape : ", cat_encoded.shape)
# Out:
# Encoded shape :  (5934, 33)

# %%
from sklearn.compose import ColumnTransformer

# %%
numeric_features = ['Reviews', 'Size', 'Installs', 'Price']
categorical_features = ['Category', 'Content Rating']

# %%
# Create ColumnTransformer

# %%
from sklearn.pipeline import Pipeline
